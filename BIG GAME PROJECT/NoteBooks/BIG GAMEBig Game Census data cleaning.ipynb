# %% [markdown]
# # Big Game Census data Cleaning

# %%
## import libraries 

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
## import dataset

Data = pd.read_excel('/Users/inazawaelectronics/Desktop/Data-Analyst-Intern-Project/BIG GAME PROJECT/Data/Big Game Census data.xlsx')
Data.head()
# Out:
#         Player Name  ...                 Birthplace, Population Data Source
# 0    Devin McCourty  ...  U.S. Census Bureau, 2012-2016 American Communi...
# 1    Danny Amendola  ...  U.S. Census Bureau, 2012-2016 American Communi...
# 2  Johnson Bademosi  ...  U.S. Census Bureau, 2012-2016 American Communi...
# 3       Chris Hogan  ...  U.S. Census Bureau, 2012-2016 American Communi...
# 4     James Develin  ...  U.S. Census Bureau, 2012-2016 American Communi...
#
# [5 rows x 24 columns]

# %%
### columns

Data.columns
# Out:
# Index(['Player Name', 'Player Jersey Number', 'Player Position', 'Player Age',
#        'Player Weight (lbs.)', 'Years Played',
#        'Player Birthplace (city, town, etc.)', 'Player Birth State',
#        'Player Birthplace (Combo)', 'Player College', 'Player Team',
#        'Conference',
#        '2016 Population Estimates (except where otherwise noted)',
#        'State GEO ID', 'Full GEOID', 'Latitude (player birthplace)',
#        'Longitude (player birthplace)', 'Number from City',
#        'Number of Records',
#        'American FactFinder Link for more Census data points',
#        'Quickfacts Link', 'State Data Link', 'Source (Population States 2017)',
#        'Birthplace, Population Data Source'],
#       dtype='object')

# %%
## dataset Shape 
Data.shape
# Out:
# (121, 24)

# %%
### find duplicate values if thare any

Data[Data.duplicated()]
# Out:
#     Player Name  ... Birthplace, Population Data Source
# 119         NaN  ...                                NaN
#
# [1 rows x 24 columns]

# %% [markdown]
# ### one duplicate value let's remove that row all are NAN values in that row

# %%
## remove duplicate row

Data.drop(119, inplace= True)

# %%
## find null values

Data.isnull().sum()
# Out:
# Player Name                                                 1
# Player Jersey Number                                        2
# Player Position                                             2
# Player Age                                                  2
# Player Weight (lbs.)                                        2
# Years Played                                                2
# Player Birthplace (city, town, etc.)                        2
# Player Birth State                                          2
# Player Birthplace (Combo)                                   2
# Player College                                              2
# Player Team                                                 2
# Conference                                                  2
# 2016 Population Estimates (except where otherwise noted)    2
# State GEO ID                                                2
# Full GEOID                                                  2
# ...

# %%
Data[Data.isnull().any(axis=1)]
# Out:
#                        Player Name  ... Birthplace, Population Data Source
# 118                            NaN  ...                                NaN
# 120  Player data from Yahoo Sports  ...                                NaN
#
# [2 rows x 24 columns]

# %%
### remove null values

Data.dropna(inplace= True)

# %%
Data.shape
# Out:
# (118, 24)

# %%
Data.to_excel('Cleaned BIG GAME Census data.xlsx')
