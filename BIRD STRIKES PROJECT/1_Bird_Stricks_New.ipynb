# %%
## Import Libraryes

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

pd.set_option('display.max_columns', None)

# %%
## Import Dataset
Data = pd.read_excel('/Users/inazawaelectronics/Desktop/PROJECTS/BIRD STRIKES PROJECT/Bird Strikes data.xlsx')
Data.head(3)
# Out:
#    Record ID Aircraft: Type                Airport: Name Altitude bin  \
# 0     202152       Airplane                 LAGUARDIA NY    > 1000 ft
# 1     208159       Airplane  DALLAS/FORT WORTH INTL ARPT    < 1000 ft
# 2     207601       Airplane            LAKEFRONT AIRPORT    < 1000 ft
#
#   Aircraft: Make/Model Wildlife: Number struck  \
# 0            B-737-400                Over 100
# 1                MD-80                Over 100
# 2                C-500                Over 100
#
#    Wildlife: Number Struck Actual Effect: Impact to flight FlightDate  \
# 0                             859         Engine Shut Down 2000-11-23
# 1                             424                     None 2001-07-25
# 2                             261                     None 2001-09-14
#
#   Effect: Indicated Damage Aircraft: Number of engines?  \
# 0            Caused damage                            2
# 1            Caused damage                            2
# 2                No damage                            2
#
#   Aircraft: Airline/Operator Origin State When: Phase of flight  \
# 0                US AIRWAYS*     New York                 Climb
# 1          AMERICAN AIRLINES        Texas          Landing Roll
# 2                   BUSINESS    Louisiana              Approach
#
#   Conditions: Precipitation  Remains of wildlife collected?  \
# 0                      None                           False
# 1                      None                           False
# 2                      None                           False
#
#    Remains of wildlife sent to Smithsonian  \
# 0                                    False
# 1                                    False
# 2                                    False
#
#                                              Remarks Wildlife: Size  \
# 0  FLT 753. PILOT REPTD A HUNDRED BIRDS ON UNKN T...         Medium
# 1  102 CARCASSES FOUND. 1 LDG LIGHT ON NOSE GEAR ...          Small
# 2  FLEW UNDER A VERY LARGE FLOCK OF BIRDS OVER AP...          Small
#
#   Conditions: Sky      Wildlife: Species Pilot warned of birds or wildlife?  \
# 0        No Cloud  Unknown bird - medium                                  N
# 1      Some Cloud            Rock pigeon                                  Y
# 2        No Cloud      European starling                                  N
#
#    Cost: Total $  Feet above ground  Number of people injured  \
# 0          30736             1500.0                         0
# 1              0                0.0                         0
# 2              0               50.0                         0
#
#   Is Aircraft Large?
# 0                Yes
# 1                 No
# 2                 No

# %%
### Read The Dataset Columns
Data.columns
# Out:
# Index(['Record ID', 'Aircraft: Type', 'Airport: Name', 'Altitude bin',
#        'Aircraft: Make/Model', 'Wildlife: Number struck',
#        'Wildlife: Number Struck Actual', 'Effect: Impact to flight',
#        'FlightDate', 'Effect: Indicated Damage',
#        'Aircraft: Number of engines?', 'Aircraft: Airline/Operator',
#        'Origin State', 'When: Phase of flight', 'Conditions: Precipitation',
#        'Remains of wildlife collected?',
#        'Remains of wildlife sent to Smithsonian', 'Remarks', 'Wildlife: Size',
#        'Conditions: Sky', 'Wildlife: Species',
#        'Pilot warned of birds or wildlife?', 'Cost: Total $',
#        'Feet above ground', 'Number of people injured', 'Is Aircraft Large?'],
#       dtype='object')

# %%
### Idendify Datatypes
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25558 entries, 0 to 25557
# Data columns (total 26 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Record ID                                25558 non-null  int64
#  1   Aircraft: Type                           25429 non-null  object
#  2   Airport: Name                            25429 non-null  object
#  3   Altitude bin                             25429 non-null  object
#  4   Aircraft: Make/Model                     25558 non-null  object
#  5   Wildlife: Number struck                  25429 non-null  object
#  6   Wildlife: Number Struck Actual           25558 non-null  int64
#  7   Effect: Impact to flight                 25429 non-null  object
#  8   FlightDate                               25429 non-null  datetime64[ns]
#  9   Effect: Indicated Damage                 25558 non-null  object
#  10  Aircraft: Number of engines?             25291 non-null  object
#  11  Aircraft: Airline/Operator               25429 non-null  object
#  12  Origin State                             25109 non-null  object
#  13  When: Phase of flight                    25429 non-null  object
#  14  Conditions: Precipitation                25558 non-null  object
#  15  Remains of wildlife collected?           25558 non-null  bool
#  16  Remains of wildlife sent to Smithsonian  25558 non-null  bool
#  17  Remarks                                  20787 non-null  object
#  18  Wildlife: Size                           25429 non-null  object
#  19  Conditions: Sky                          25558 non-null  object
#  20  Wildlife: Species                        25558 non-null  object
#  21  Pilot warned of birds or wildlife?       25429 non-null  object
#  22  Cost: Total $                            25558 non-null  int64
#  23  Feet above ground                        25429 non-null  float64
#  24  Number of people injured                 25558 non-null  int64
#  25  Is Aircraft Large?                       25429 non-null  object
# dtypes: bool(2), datetime64[ns](1), float64(1), int64(4), object(18)
# memory usage: 4.7+ MB

# %%
Data.shape
# Out:
# (25558, 26)

# %%
len(Data['Record ID'].unique())
# Out:
# 25558

# %%
#### Drop the Record ID Column in Dataset 
Data.drop('Record ID', axis= 1, inplace= True)

# %%
### find how many Duplicated rows in this Dataset
len(Data[Data.duplicated()])
# Out:
# 10

# %%
### Remove Duplicates
Data.drop_duplicates(inplace= True)

# %%
Data.shape
# Out:
# (25548, 25)

# %%
### Find the NAN Values Percentages
Data.isnull().mean() * 100
# Out:
# Aircraft: Type                              0.504932
# Airport: Name                               0.504932
# Altitude bin                                0.504932
# Aircraft: Make/Model                        0.000000
# Wildlife: Number struck                     0.504932
# Wildlife: Number Struck Actual              0.000000
# Effect: Impact to flight                    0.504932
# FlightDate                                  0.504932
# Effect: Indicated Damage                    0.000000
# Aircraft: Number of engines?                1.045092
# Aircraft: Airline/Operator                  0.504932
# Origin State                                1.757476
# When: Phase of flight                       0.504932
# Conditions: Precipitation                   0.000000
# Remains of wildlife collected?              0.000000
# Remains of wildlife sent to Smithsonian     0.000000
# Remarks                                    18.662909
# Wildlife: Size                              0.504932
# Conditions: Sky                             0.000000
# Wildlife: Species                           0.000000
# Pilot warned of birds or wildlife?          0.504932
# Cost: Total $                               0.000000
# Feet above ground                           0.504932
# Number of people injured                    0.000000
# Is Aircraft Large?                          0.504932
# dtype: float64

# %%
sns.heatmap(Data.isnull(), cmap= 'viridis', yticklabels= False)
# Out:
# <Axes: >

# %%
Data['Remarks'].isnull().sum()
# Out:
# 4768

# %%
len(Data['Remarks'].unique())
# Out:
# 18187

# %%
Data['Remarks'].value_counts().sort_values(ascending=False).head(10)
# Out:
# NO DMG.                                                           739
# NO DMG                                                            395
# ATIS WARNING.                                                     165
# ATIS WARNING                                                      135
# # STRUCK NOT REPTD, ASSUME 1, SAME AS # SEEN.                      72
# ATIS WARNING. NO DMG.                                              53
# NO DMG REPTD.                                                      49
# ID BY SMITHSONIAN.                                                 44
# DATA ENTRY NOTE: # STRUCK NOT REPTD, ASSUME 1, SAME AS # SEEN.     43
# # STRUCK NOT REPTD, ASSUME 1.                                      42
# Name: Remarks, dtype: int64

# %%
Data.describe().T
# Out:
#                                   count         mean            std  min  25%  \
# Wildlife: Number Struck Actual  25548.0     2.692187      12.796435  1.0  1.0
# Cost: Total $                   25548.0  5569.533623  121995.087626  0.0  0.0
# Feet above ground               25419.0   799.184822    1740.356669  0.0  0.0
# Number of people injured        25548.0     0.001057       0.050430  0.0  0.0
#
#                                  50%    75%         max
# Wildlife: Number Struck Actual   1.0    1.0       942.0
# Cost: Total $                    0.0    0.0  12397751.0
# Feet above ground               50.0  700.0     18000.0
# Number of people injured         0.0    0.0         6.0

# %%
categorical_features = [feature for feature in Data.columns if Data[feature].dtypes == 'O']
numarical_features = [feature for feature in Data.columns if Data[feature].dtypes != 'O']

# %%
Data[categorical_features].head()
# Out:
#   Aircraft: Type                Airport: Name Altitude bin  \
# 0       Airplane                 LAGUARDIA NY    > 1000 ft
# 1       Airplane  DALLAS/FORT WORTH INTL ARPT    < 1000 ft
# 2       Airplane            LAKEFRONT AIRPORT    < 1000 ft
# 3       Airplane          SEATTLE-TACOMA INTL    < 1000 ft
# 4       Airplane                 NORFOLK INTL    < 1000 ft
#
#   Aircraft: Make/Model Wildlife: Number struck Effect: Impact to flight  \
# 0            B-737-400                Over 100         Engine Shut Down
# 1                MD-80                Over 100                     None
# 2                C-500                Over 100                     None
# 3            B-737-400                Over 100    Precautionary Landing
# 4         CL-RJ100/200                Over 100                     None
#
#   Effect: Indicated Damage Aircraft: Number of engines?  \
# 0            Caused damage                            2
# 1            Caused damage                            2
# 2                No damage                            2
# 3                No damage                            2
# 4                No damage                            2
#
#   Aircraft: Airline/Operator Origin State When: Phase of flight  \
# 0                US AIRWAYS*     New York                 Climb
# 1          AMERICAN AIRLINES        Texas          Landing Roll
# 2                   BUSINESS    Louisiana              Approach
# 3            ALASKA AIRLINES   Washington                 Climb
# 4            COMAIR AIRLINES     Virginia              Approach
#
#   Conditions: Precipitation  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
#
#                                              Remarks Wildlife: Size  \
# 0  FLT 753. PILOT REPTD A HUNDRED BIRDS ON UNKN T...         Medium
# 1  102 CARCASSES FOUND. 1 LDG LIGHT ON NOSE GEAR ...          Small
# 2  FLEW UNDER A VERY LARGE FLOCK OF BIRDS OVER AP...          Small
# 3  NOTAM WARNING. 26 BIRDS HIT THE A/C, FORCING A...          Small
# 4                                      NO DMG REPTD.          Small
#
#   Conditions: Sky      Wildlife: Species Pilot warned of birds or wildlife?  \
# 0        No Cloud  Unknown bird - medium                                  N
# 1      Some Cloud            Rock pigeon                                  Y
# 2        No Cloud      European starling                                  N
# 3      Some Cloud      European starling                                  Y
# 4        No Cloud      European starling                                  N
#
#   Is Aircraft Large?
# 0                Yes
# 1                 No
# 2                 No
# 3                Yes
# 4                 No

# %%
Data[categorical_features].isnull().sum()
# Out:
# Aircraft: Type                         129
# Airport: Name                          129
# Altitude bin                           129
# Aircraft: Make/Model                     0
# Wildlife: Number struck                129
# Effect: Impact to flight               129
# Effect: Indicated Damage                 0
# Aircraft: Number of engines?           267
# Aircraft: Airline/Operator             129
# Origin State                           449
# When: Phase of flight                  129
# Conditions: Precipitation                0
# Remarks                               4768
# Wildlife: Size                         129
# Conditions: Sky                          0
# Wildlife: Species                        0
# Pilot warned of birds or wildlife?     129
# Is Aircraft Large?                     129
# dtype: int64

# %%
for feature in categorical_features:
    print(feature, '---> Label Count : ', len(Data[feature].unique()))
# Out:
# Aircraft: Type ---> Label Count :  2
# Airport: Name ---> Label Count :  1110
# Altitude bin ---> Label Count :  3
# Aircraft: Make/Model ---> Label Count :  351
# Wildlife: Number struck ---> Label Count :  5
# Effect: Impact to flight ---> Label Count :  6
# Effect: Indicated Damage ---> Label Count :  2
# Aircraft: Number of engines? ---> Label Count :  6
# Aircraft: Airline/Operator ---> Label Count :  293
# Origin State ---> Label Count :  61
# When: Phase of flight ---> Label Count :  8
# Conditions: Precipitation ---> Label Count :  8
# Remarks ---> Label Count :  18187
# Wildlife: Size ---> Label Count :  4
# Conditions: Sky ---> Label Count :  3
# Wildlife: Species ---> Label Count :  348
# Pilot warned of birds or wildlife? ---> Label Count :  3
# Is Aircraft Large? ---> Label Count :  3

# %%
Data[numarical_features].isnull().sum()
# Out:
# Wildlife: Number Struck Actual               0
# FlightDate                                 129
# Remains of wildlife collected?               0
# Remains of wildlife sent to Smithsonian      0
# Cost: Total $                                0
# Feet above ground                          129
# Number of people injured                     0
# dtype: int64

# %%
Data.head(2)
# Out:
#   Aircraft: Type                Airport: Name Altitude bin  \
# 0       Airplane                 LAGUARDIA NY    > 1000 ft
# 1       Airplane  DALLAS/FORT WORTH INTL ARPT    < 1000 ft
#
#   Aircraft: Make/Model Wildlife: Number struck  \
# 0            B-737-400                Over 100
# 1                MD-80                Over 100
#
#    Wildlife: Number Struck Actual Effect: Impact to flight FlightDate  \
# 0                             859         Engine Shut Down 2000-11-23
# 1                             424                     None 2001-07-25
#
#   Effect: Indicated Damage Aircraft: Number of engines?  \
# 0            Caused damage                            2
# 1            Caused damage                            2
#
#   Aircraft: Airline/Operator Origin State When: Phase of flight  \
# 0                US AIRWAYS*     New York                 Climb
# 1          AMERICAN AIRLINES        Texas          Landing Roll
#
#   Conditions: Precipitation  Remains of wildlife collected?  \
# 0                      None                           False
# 1                      None                           False
#
#    Remains of wildlife sent to Smithsonian  \
# 0                                    False
# 1                                    False
#
#                                              Remarks Wildlife: Size  \
# 0  FLT 753. PILOT REPTD A HUNDRED BIRDS ON UNKN T...         Medium
# 1  102 CARCASSES FOUND. 1 LDG LIGHT ON NOSE GEAR ...          Small
#
#   Conditions: Sky      Wildlife: Species Pilot warned of birds or wildlife?  \
# 0        No Cloud  Unknown bird - medium                                  N
# 1      Some Cloud            Rock pigeon                                  Y
#
#    Cost: Total $  Feet above ground  Number of people injured  \
# 0          30736             1500.0                         0
# 1              0                0.0                         0
#
#   Is Aircraft Large?
# 0                Yes
# 1                 No

# %%
Data.dropna(subset=['FlightDate'], inplace= True)

# %%
Data['FlightDate'].isnull().sum()
# Out:
# 0

# %%
sns.histplot(Data['Feet above ground'], bins= 50)
# Out:
# <Axes: xlabel='Feet above ground', ylabel='Count'>

# %%
Data['Feet above ground'].fillna(Data['Feet above ground'].mean(), inplace= True)

# %%
Data[numarical_features].isnull().sum()
# Out:
# Wildlife: Number Struck Actual             0
# FlightDate                                 0
# Remains of wildlife collected?             0
# Remains of wildlife sent to Smithsonian    0
# Cost: Total $                              0
# Feet above ground                          0
# Number of people injured                   0
# dtype: int64

# %%
Data.shape
# Out:
# (25419, 25)

# %%
Data[categorical_features].isnull().sum()
# Out:
# Aircraft: Type                           0
# Airport: Name                            0
# Altitude bin                             0
# Aircraft: Make/Model                     0
# Wildlife: Number struck                  0
# Effect: Impact to flight                 0
# Effect: Indicated Damage                 0
# Aircraft: Number of engines?           234
# Aircraft: Airline/Operator               0
# Origin State                           449
# When: Phase of flight                    0
# Conditions: Precipitation                0
# Remarks                               4758
# Wildlife: Size                           0
# Conditions: Sky                          0
# Wildlife: Species                        0
# Pilot warned of birds or wildlife?       0
# Is Aircraft Large?                       0
# dtype: int64

# %%
Data[categorical_features].fillna('Missing', inplace= True)
# Out:
# /var/folders/8h/34w8609j6936zp6y_871bvk00000gn/T/ipykernel_84515/22853635.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data[categorical_features].fillna('Missing', inplace= True)

# %%
Data[categorical_features].head()
# Out:
#   Aircraft: Type                Airport: Name Altitude bin  \
# 0       Airplane                 LAGUARDIA NY    > 1000 ft
# 1       Airplane  DALLAS/FORT WORTH INTL ARPT    < 1000 ft
# 2       Airplane            LAKEFRONT AIRPORT    < 1000 ft
# 3       Airplane          SEATTLE-TACOMA INTL    < 1000 ft
# 4       Airplane                 NORFOLK INTL    < 1000 ft
#
#   Aircraft: Make/Model Wildlife: Number struck Effect: Impact to flight  \
# 0            B-737-400                Over 100         Engine Shut Down
# 1                MD-80                Over 100                     None
# 2                C-500                Over 100                     None
# 3            B-737-400                Over 100    Precautionary Landing
# 4         CL-RJ100/200                Over 100                     None
#
#   Effect: Indicated Damage Aircraft: Number of engines?  \
# 0            Caused damage                            2
# 1            Caused damage                            2
# 2                No damage                            2
# 3                No damage                            2
# 4                No damage                            2
#
#   Aircraft: Airline/Operator Origin State When: Phase of flight  \
# 0                US AIRWAYS*     New York                 Climb
# 1          AMERICAN AIRLINES        Texas          Landing Roll
# 2                   BUSINESS    Louisiana              Approach
# 3            ALASKA AIRLINES   Washington                 Climb
# 4            COMAIR AIRLINES     Virginia              Approach
#
#   Conditions: Precipitation  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
#
#                                              Remarks Wildlife: Size  \
# 0  FLT 753. PILOT REPTD A HUNDRED BIRDS ON UNKN T...         Medium
# 1  102 CARCASSES FOUND. 1 LDG LIGHT ON NOSE GEAR ...          Small
# 2  FLEW UNDER A VERY LARGE FLOCK OF BIRDS OVER AP...          Small
# 3  NOTAM WARNING. 26 BIRDS HIT THE A/C, FORCING A...          Small
# 4                                      NO DMG REPTD.          Small
#
#   Conditions: Sky      Wildlife: Species Pilot warned of birds or wildlife?  \
# 0        No Cloud  Unknown bird - medium                                  N
# 1      Some Cloud            Rock pigeon                                  Y
# 2        No Cloud      European starling                                  N
# 3      Some Cloud      European starling                                  Y
# 4        No Cloud      European starling                                  N
#
#   Is Aircraft Large?
# 0                Yes
# 1                 No
# 2                 No
# 3                Yes
# 4                 No

# %%
Data['Effect: Indicated Damage'].value_counts()
# Out:
# No damage        22965
# Caused damage     2454
# Name: Effect: Indicated Damage, dtype: int64

# %%
Data['Effect: Indicated Damage'][Data['Effect: Indicated Damage'] == 'No damage'] = 0
Data['Effect: Indicated Damage'][Data['Effect: Indicated Damage'] == 'Caused damage'] = 1
# Out:
# /var/folders/8h/34w8609j6936zp6y_871bvk00000gn/T/ipykernel_84515/458085608.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['Effect: Indicated Damage'][Data['Effect: Indicated Damage'] == 'No damage'] = 0
# /var/folders/8h/34w8609j6936zp6y_871bvk00000gn/T/ipykernel_84515/458085608.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['Effect: Indicated Damage'][Data['Effect: Indicated Damage'] == 'Caused damage'] = 1

# %%
Data['Effect: Indicated Damage'] = Data['Effect: Indicated Damage'].astype(int)

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25419 entries, 0 to 25557
# Data columns (total 25 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Aircraft: Type                           25419 non-null  object
#  1   Airport: Name                            25419 non-null  object
#  2   Altitude bin                             25419 non-null  object
#  3   Aircraft: Make/Model                     25419 non-null  object
#  4   Wildlife: Number struck                  25419 non-null  object
#  5   Wildlife: Number Struck Actual           25419 non-null  int64
#  6   Effect: Impact to flight                 25419 non-null  object
#  7   FlightDate                               25419 non-null  datetime64[ns]
#  8   Effect: Indicated Damage                 25419 non-null  int64
#  9   Aircraft: Number of engines?             25185 non-null  object
#  10  Aircraft: Airline/Operator               25419 non-null  object
#  11  Origin State                             24970 non-null  object
#  12  When: Phase of flight                    25419 non-null  object
#  13  Conditions: Precipitation                25419 non-null  object
#  14  Remains of wildlife collected?           25419 non-null  bool
#  15  Remains of wildlife sent to Smithsonian  25419 non-null  bool
#  16  Remarks                                  20661 non-null  object
#  17  Wildlife: Size                           25419 non-null  object
#  18  Conditions: Sky                          25419 non-null  object
#  19  Wildlife: Species                        25419 non-null  object
#  20  Pilot warned of birds or wildlife?       25419 non-null  object
#  21  Cost: Total $                            25419 non-null  int64
#  22  Feet above ground                        25419 non-null  float64
#  23  Number of people injured                 25419 non-null  int64
#  24  Is Aircraft Large?                       25419 non-null  object
# dtypes: bool(2), datetime64[ns](1), float64(1), int64(4), object(17)
# memory usage: 4.7+ MB

# %%
Data.isnull().sum()
# Out:
# Aircraft: Type                                0
# Airport: Name                                 0
# Altitude bin                                  0
# Aircraft: Make/Model                          0
# Wildlife: Number struck                       0
# Wildlife: Number Struck Actual                0
# Effect: Impact to flight                      0
# FlightDate                                    0
# Effect: Indicated Damage                      0
# Aircraft: Number of engines?                234
# Aircraft: Airline/Operator                    0
# Origin State                                449
# When: Phase of flight                         0
# Conditions: Precipitation                     0
# Remains of wildlife collected?                0
# Remains of wildlife sent to Smithsonian       0
# Remarks                                    4758
# Wildlife: Size                                0
# Conditions: Sky                               0
# Wildlife: Species                             0
# Pilot warned of birds or wildlife?            0
# Cost: Total $                                 0
# Feet above ground                             0
# Number of people injured                      0
# Is Aircraft Large?                            0
# dtype: int64

# %%
Data['Aircraft: Number of engines?'].fillna('')
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 25552    2
# 25553    2
# 25554    2
# 25556    2
# 25557    2
# Name: Aircraft: Number of engines?, Length: 25419, dtype: object

# %%
Data.head()
# Out:
#   Aircraft: Type                Airport: Name Altitude bin  \
# 0       Airplane                 LAGUARDIA NY    > 1000 ft
# 1       Airplane  DALLAS/FORT WORTH INTL ARPT    < 1000 ft
# 2       Airplane            LAKEFRONT AIRPORT    < 1000 ft
# 3       Airplane          SEATTLE-TACOMA INTL    < 1000 ft
# 4       Airplane                 NORFOLK INTL    < 1000 ft
#
#   Aircraft: Make/Model Wildlife: Number struck  \
# 0            B-737-400                Over 100
# 1                MD-80                Over 100
# 2                C-500                Over 100
# 3            B-737-400                Over 100
# 4         CL-RJ100/200                Over 100
#
#    Wildlife: Number Struck Actual Effect: Impact to flight FlightDate  \
# 0                             859         Engine Shut Down 2000-11-23
# 1                             424                     None 2001-07-25
# 2                             261                     None 2001-09-14
# 3                             806    Precautionary Landing 2002-09-05
# 4                             942                     None 2003-06-23
#
#    Effect: Indicated Damage Aircraft: Number of engines?  \
# 0                         1                            2
# 1                         1                            2
# 2                         0                            2
# 3                         0                            2
# 4                         0                            2
#
#   Aircraft: Airline/Operator Origin State When: Phase of flight  \
# 0                US AIRWAYS*     New York                 Climb
# 1          AMERICAN AIRLINES        Texas          Landing Roll
# 2                   BUSINESS    Louisiana              Approach
# 3            ALASKA AIRLINES   Washington                 Climb
# 4            COMAIR AIRLINES     Virginia              Approach
#
#   Conditions: Precipitation  Remains of wildlife collected?  \
# 0                      None                           False
# 1                      None                           False
# 2                      None                           False
# 3                      None                            True
# 4                      None                           False
#
#    Remains of wildlife sent to Smithsonian  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#                                              Remarks Wildlife: Size  \
# 0  FLT 753. PILOT REPTD A HUNDRED BIRDS ON UNKN T...         Medium
# 1  102 CARCASSES FOUND. 1 LDG LIGHT ON NOSE GEAR ...          Small
# 2  FLEW UNDER A VERY LARGE FLOCK OF BIRDS OVER AP...          Small
# 3  NOTAM WARNING. 26 BIRDS HIT THE A/C, FORCING A...          Small
# 4                                      NO DMG REPTD.          Small
#
#   Conditions: Sky      Wildlife: Species Pilot warned of birds or wildlife?  \
# 0        No Cloud  Unknown bird - medium                                  N
# 1      Some Cloud            Rock pigeon                                  Y
# 2        No Cloud      European starling                                  N
# 3      Some Cloud      European starling                                  Y
# 4        No Cloud      European starling                                  N
#
#    Cost: Total $  Feet above ground  Number of people injured  \
# 0          30736             1500.0                         0
# 1              0                0.0                         0
# 2              0               50.0                         0
# 3              0               50.0                         0
# 4              0               50.0                         0
#
#   Is Aircraft Large?
# 0                Yes
# 1                 No
# 2                 No
# 3                Yes
# 4                 No

# %%
Data['Aircraft: Number of engines?'].value_counts()
# Out:
# 2    22993
# 1     1239
# 3      564
# 4      388
# C        1
# Name: Aircraft: Number of engines?, dtype: int64

# %%
Data[Data['Aircraft: Number of engines?'] == 'C']
# Out:
#      Aircraft: Type              Airport: Name Altitude bin  \
# 6664       Airplane  MORGANTOWN MUNICIPAL ARPT    > 1000 ft
#
#      Aircraft: Make/Model Wildlife: Number struck  \
# 6664         RKWLTRBO 690                       1
#
#       Wildlife: Number Struck Actual Effect: Impact to flight FlightDate  \
# 6664                               1                     None 2001-11-05
#
#       Effect: Indicated Damage Aircraft: Number of engines?  \
# 6664                         0                            C
#
#      Aircraft: Airline/Operator   Origin State When: Phase of flight  \
# 6664                   BUSINESS  West Virginia               Descent
#
#      Conditions: Precipitation  Remains of wildlife collected?  \
# 6664                      None                           False
#
#       Remains of wildlife sent to Smithsonian  \
# 6664                                    False
#
#                                                 Remarks Wildlife: Size  \
# 6664  PILOT ADZ NO DMG. INFO RELAYED TO CKB THRU MGW...         Medium
#
#      Conditions: Sky      Wildlife: Species  \
# 6664        No Cloud  Unknown bird - medium
#
#      Pilot warned of birds or wildlife?  Cost: Total $  Feet above ground  \
# 6664                                  N              0             4000.0
#
#       Number of people injured Is Aircraft Large?
# 6664                         0                 No

# %%
Data.drop(6664, inplace= True)

# %%
Data[Data['Aircraft: Number of engines?'] == 'C']
# Out:
# Empty DataFrame
# Columns: [Aircraft: Type, Airport: Name, Altitude bin, Aircraft: Make/Model, Wildlife: Number struck, Wildlife: Number Struck Actual, Effect: Impact to flight, FlightDate, Effect: Indicated Damage, Aircraft: Number of engines?, Aircraft: Airline/Operator, Origin State, When: Phase of flight, Conditions: Precipitation, Remains of wildlife collected?, Remains of wildlife sent to Smithsonian, Remarks, Wildlife: Size, Conditions: Sky, Wildlife: Species, Pilot warned of birds or wildlife?, Cost: Total $, Feet above ground, Number of people injured, Is Aircraft Large?]
# Index: []

# %%
Data['Aircraft: Number of engines?'].value_counts()
# Out:
# 2    22993
# 1     1239
# 3      564
# 4      388
# Name: Aircraft: Number of engines?, dtype: int64

# %%
mod = Data['Aircraft: Number of engines?'].mode()[0]
Data['Aircraft: Number of engines?'].fillna(mod, inplace= True)

# %%
Data['Aircraft: Number of engines?'].dtype
# Out:
# dtype('int64')

# %%
Data.isnull().sum()
# Out:
# Aircraft: Type                                0
# Airport: Name                                 0
# Altitude bin                                  0
# Aircraft: Make/Model                          0
# Wildlife: Number struck                       0
# Wildlife: Number Struck Actual                0
# Effect: Impact to flight                      0
# FlightDate                                    0
# Effect: Indicated Damage                      0
# Aircraft: Number of engines?                  0
# Aircraft: Airline/Operator                    0
# Origin State                                449
# When: Phase of flight                         0
# Conditions: Precipitation                     0
# Remains of wildlife collected?                0
# Remains of wildlife sent to Smithsonian       0
# Remarks                                    4758
# Wildlife: Size                                0
# Conditions: Sky                               0
# Wildlife: Species                             0
# Pilot warned of birds or wildlife?            0
# Cost: Total $                                 0
# Feet above ground                             0
# Number of people injured                      0
# Is Aircraft Large?                            0
# dtype: int64

# %%
### Replave The Origin State NAN VAlues With most Frequent Values
len(Data['Origin State'].unique())
freq = Data['Origin State'].value_counts().sort_values(ascending= False)[0]
Data['Origin State'].fillna(freq, inplace= True)

# %%
### Let's Replace Remarks NAN Values With New Label 'Missing' 
Data['Remarks'].fillna('Missing', inplace= True)

# %%
Data.isnull().sum()
# Out:
# Aircraft: Type                             0
# Airport: Name                              0
# Altitude bin                               0
# Aircraft: Make/Model                       0
# Wildlife: Number struck                    0
# Wildlife: Number Struck Actual             0
# Effect: Impact to flight                   0
# FlightDate                                 0
# Effect: Indicated Damage                   0
# Aircraft: Number of engines?               0
# Aircraft: Airline/Operator                 0
# Origin State                               0
# When: Phase of flight                      0
# Conditions: Precipitation                  0
# Remains of wildlife collected?             0
# Remains of wildlife sent to Smithsonian    0
# Remarks                                    0
# Wildlife: Size                             0
# Conditions: Sky                            0
# Wildlife: Species                          0
# Pilot warned of birds or wildlife?         0
# Cost: Total $                              0
# Feet above ground                          0
# Number of people injured                   0
# Is Aircraft Large?                         0
# dtype: int64

# %%
Data.head(3)
# Out:
#   Aircraft: Type                Airport: Name Altitude bin  \
# 0       Airplane                 LAGUARDIA NY    > 1000 ft
# 1       Airplane  DALLAS/FORT WORTH INTL ARPT    < 1000 ft
# 2       Airplane            LAKEFRONT AIRPORT    < 1000 ft
#
#   Aircraft: Make/Model Wildlife: Number struck  \
# 0            B-737-400                Over 100
# 1                MD-80                Over 100
# 2                C-500                Over 100
#
#    Wildlife: Number Struck Actual Effect: Impact to flight FlightDate  \
# 0                             859         Engine Shut Down 2000-11-23
# 1                             424                     None 2001-07-25
# 2                             261                     None 2001-09-14
#
#    Effect: Indicated Damage  Aircraft: Number of engines?  \
# 0                         1                             2
# 1                         1                             2
# 2                         0                             2
#
#   Aircraft: Airline/Operator Origin State When: Phase of flight  \
# 0                US AIRWAYS*     New York                 Climb
# 1          AMERICAN AIRLINES        Texas          Landing Roll
# 2                   BUSINESS    Louisiana              Approach
#
#   Conditions: Precipitation  Remains of wildlife collected?  \
# 0                      None                           False
# 1                      None                           False
# 2                      None                           False
#
#    Remains of wildlife sent to Smithsonian  \
# 0                                    False
# 1                                    False
# 2                                    False
#
#                                              Remarks Wildlife: Size  \
# 0  FLT 753. PILOT REPTD A HUNDRED BIRDS ON UNKN T...         Medium
# 1  102 CARCASSES FOUND. 1 LDG LIGHT ON NOSE GEAR ...          Small
# 2  FLEW UNDER A VERY LARGE FLOCK OF BIRDS OVER AP...          Small
#
#   Conditions: Sky      Wildlife: Species Pilot warned of birds or wildlife?  \
# 0        No Cloud  Unknown bird - medium                                  N
# 1      Some Cloud            Rock pigeon                                  Y
# 2        No Cloud      European starling                                  N
#
#    Cost: Total $  Feet above ground  Number of people injured  \
# 0          30736             1500.0                         0
# 1              0                0.0                         0
# 2              0               50.0                         0
#
#   Is Aircraft Large?
# 0                Yes
# 1                 No
# 2                 No

# %%
plt.pie(Data['Effect: Indicated Damage'].value_counts().values, labels= Data['Effect: Indicated Damage'].value_counts().index,autopct= "%0.1f%%")
plt.show()

# %%
#### Identify The Bird Strick Trend Using Line plot

Data['Year'] = Data['FlightDate'].dt.year

Data.groupby('Year')['Effect: Indicated Damage'].sum().plot.line()

plt.title('Bird Strick Trend (2000 - 2011)')
plt.xlabel('Year')
plt.ylabel('Bird Strick Count')
plt.show()

# %% [markdown]
# ##### Observation
#
# 1. Very Low Bird Strick Count in 2001
# 2. Very Heigh Bird Strick Count in 2010
# 3. in 2011 Bird Strick Count are Heuge drop to compare with 2010

# %%
Data['Year'].unique()
# Out:
# array([2000, 2001, 2002, 2003, 2006, 2004, 2005, 2007, 2008, 2009, 2010,
#        2011])

# %%
Data.groupby(['Year','Altitude bin'])[['Effect: Indicated Damage']].sum()
# Out:
#                    Effect: Indicated Damage
# Year Altitude bin
# 2000 < 1000 ft                          122
#      > 1000 ft                           74
# 2001 < 1000 ft                           90
#      > 1000 ft                           33
# 2002 < 1000 ft                          124
#      > 1000 ft                           62
# 2003 < 1000 ft                          141
#      > 1000 ft                           60
# 2004 < 1000 ft                          137
#      > 1000 ft                           47
# 2005 < 1000 ft                          128
#      > 1000 ft                           52
# 2006 < 1000 ft                          160
#      > 1000 ft                           72
# 2007 < 1000 ft                          156
#      > 1000 ft                           61
# 2008 < 1000 ft                          150
#      > 1000 ft                           68
# 2009 < 1000 ft                          179
#      > 1000 ft                           71
# 2010 < 1000 ft                          174
#      > 1000 ft                           80
# 2011 < 1000 ft                          141
#      > 1000 ft                           72

# %%
Data.groupby('Altitude bin')['Effect: Indicated Damage'].sum().plot.bar()
# Out:
# <Axes: xlabel='Altitude bin'>

# %% [markdown]
# #### Observation
#
# Most Of The Damage Indicated in below 1000 Feet

# %%
# Convert 'Effect: Indicated Damage' to integer (True = 1, False = 0)
Data['Effect: Indicated Damage'] = Data['Effect: Indicated Damage'].astype(int)

# Group by 'Year' and 'Altitude bin' and sum the 'Effect: Indicated Damage'
grouped_data = Data.groupby(['Year', 'Altitude bin'], as_index=False)['Effect: Indicated Damage'].sum()

# Plot using Seaborn lineplot
plt.figure(figsize=(12, 6))
sns.lineplot(data=grouped_data, x='Year', y='Effect: Indicated Damage', hue='Altitude bin')

# Customize the plot
plt.title('Bird Strikes with Indicated Damage per Year by Altitude Bin')
plt.xlabel('Year')
plt.ylabel('Number of Bird Strikes with Indicated Damage')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(title='Altitude Bin', loc='upper left')

# Display the plot
plt.show()

# %% [markdown]
# ##### Observation
#
# Every Year Damage indicated in below 1000 Feet

# %%
# Convert 'Effect: Indicated Damage' to integer (True = 1, False = 0)
#Data['Effect: Indicated Damage'] = Data['Effect: Indicated Damage'].astype(int)

# Group by 'Year' and 'Altitude bin', and sum the 'Effect: Indicated Damage'
grouped_data = Data.groupby(['Year', 'Conditions: Sky'], as_index=False)['Effect: Indicated Damage'].sum()

# Plot using Seaborn barplot
plt.figure(figsize=(12, 6))
sns.barplot(data=grouped_data, x='Year', y='Effect: Indicated Damage', hue='Conditions: Sky')

# Customize the plot
plt.title('Bird Strikes with Indicated Damage per Year by Sky Conditions')
plt.xlabel('Year')
plt.ylabel('Number of Bird Strikes with Indicated Damage')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Display the plot
plt.show()

# %% [markdown]
# #### Observation
#
# 1. Every Year Most of The Damage Indicated in (No Cloud Sky Condition)
# 2. Every Year least of The Damage Indicated in (Overcast Sky Condition)
#
# Total Damage Indicaded ------------ (No Cloud > Some Cloud > Overcast) Sky Condition

# %%
Data.columns
# Out:
# Index(['Aircraft: Type', 'Airport: Name', 'Altitude bin',
#        'Aircraft: Make/Model', 'Wildlife: Number struck',
#        'Wildlife: Number Struck Actual', 'Effect: Impact to flight',
#        'FlightDate', 'Effect: Indicated Damage',
#        'Aircraft: Number of engines?', 'Aircraft: Airline/Operator',
#        'Origin State', 'When: Phase of flight', 'Conditions: Precipitation',
#        'Remains of wildlife collected?',
#        'Remains of wildlife sent to Smithsonian', 'Remarks', 'Wildlife: Size',
#        'Conditions: Sky', 'Wildlife: Species',
#        'Pilot warned of birds or wildlife?', 'Cost: Total $',
#        'Feet above ground', 'Number of people injured', 'Is Aircraft Large?',
#        'Year'],
#       dtype='object')

# %%
Data['Wildlife: Size'].unique()
# Out:
# array(['Medium', 'Small', 'Large'], dtype=object)

# %%
# Convert 'Effect: Indicated Damage' to integer (True = 1, False = 0)
Data['Effect: Indicated Damage'] = Data['Effect: Indicated Damage'].astype(int)

# Group by 'Year' and 'Altitude bin' and sum the 'Effect: Indicated Damage'
grouped_data = Data.groupby(['Year', 'Wildlife: Size'], as_index=False)['Effect: Indicated Damage'].sum()

# Plot using Seaborn lineplot
plt.figure(figsize=(12, 6))
sns.lineplot(data=grouped_data, x='Year', y='Effect: Indicated Damage', hue='Wildlife: Size')

# Customize the plot
plt.title('Bird Strikes with Indicated Damage per Year by Altitude Bin')
plt.xlabel('Year')
plt.ylabel('Number of Bird Strikes with Indicated Damage')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(title='Altitude Bin', loc='upper left')

# Display the plot
plt.show()

# %%
Data.head(2)
# Out:
#   Aircraft: Type                Airport: Name Altitude bin  \
# 0       Airplane                 LAGUARDIA NY    > 1000 ft
# 1       Airplane  DALLAS/FORT WORTH INTL ARPT    < 1000 ft
#
#   Aircraft: Make/Model Wildlife: Number struck  \
# 0            B-737-400                Over 100
# 1                MD-80                Over 100
#
#    Wildlife: Number Struck Actual Effect: Impact to flight FlightDate  \
# 0                             859         Engine Shut Down 2000-11-23
# 1                             424                     None 2001-07-25
#
#    Effect: Indicated Damage  Aircraft: Number of engines?  \
# 0                         1                             2
# 1                         1                             2
#
#   Aircraft: Airline/Operator Origin State When: Phase of flight  \
# 0                US AIRWAYS*     New York                 Climb
# 1          AMERICAN AIRLINES        Texas          Landing Roll
#
#   Conditions: Precipitation  Remains of wildlife collected?  \
# 0                      None                           False
# 1                      None                           False
#
#    Remains of wildlife sent to Smithsonian  \
# 0                                    False
# 1                                    False
#
#                                              Remarks Wildlife: Size  \
# 0  FLT 753. PILOT REPTD A HUNDRED BIRDS ON UNKN T...         Medium
# 1  102 CARCASSES FOUND. 1 LDG LIGHT ON NOSE GEAR ...          Small
#
#   Conditions: Sky      Wildlife: Species Pilot warned of birds or wildlife?  \
# 0        No Cloud  Unknown bird - medium                                  N
# 1      Some Cloud            Rock pigeon                                  Y
#
#    Cost: Total $  Feet above ground  Number of people injured  \
# 0          30736             1500.0                         0
# 1              0                0.0                         0
#
#   Is Aircraft Large?  Year
# 0                Yes  2000
# 1                 No  2001

# %%
Species_grouped_data = Data.groupby(['Wildlife: Species'])['Effect: Indicated Damage'].sum().sort_values(ascending=False).reset_index().head(10)

# Plot using Seaborn lineplot
plt.figure(figsize=(12, 6))
sns.barplot(data=Species_grouped_data, x='Wildlife: Species', y='Effect: Indicated Damage')

# Customize the plot
plt.title('Top 10 Species (Indicated Damage)')
plt.xlabel('Top 10 Species')
plt.ylabel('Number of Top 10 Bird Strikes ')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)


# Display the plot
plt.show()

# %%
### Top 5 Origine State with Most Damage Indicated

top5_originestate = Data.groupby(['Origin State'])['Effect: Indicated Damage'].sum().sort_values(ascending=False).head(5)

plt.pie(top5_originestate.values, labels= top5_originestate.index, autopct= '%0.1f%%')

plt.title('Top 5 Most Damage Indicated Origine State')

plt.show()

# %%
Data.groupby('Wildlife: Number struck')['Effect: Indicated Damage'].sum().sort_values(ascending=False).plot.bar()

plt.xticks(rotation=0)
plt.show()

# %%
Data.head(2)
# Out:
#   Aircraft: Type                Airport: Name Altitude bin  \
# 0       Airplane                 LAGUARDIA NY    > 1000 ft
# 1       Airplane  DALLAS/FORT WORTH INTL ARPT    < 1000 ft
#
#   Aircraft: Make/Model Wildlife: Number struck  \
# 0            B-737-400                Over 100
# 1                MD-80                Over 100
#
#    Wildlife: Number Struck Actual Effect: Impact to flight FlightDate  \
# 0                             859         Engine Shut Down 2000-11-23
# 1                             424                     None 2001-07-25
#
#    Effect: Indicated Damage  Aircraft: Number of engines?  \
# 0                         1                             2
# 1                         1                             2
#
#   Aircraft: Airline/Operator Origin State When: Phase of flight  \
# 0                US AIRWAYS*     New York                 Climb
# 1          AMERICAN AIRLINES        Texas          Landing Roll
#
#   Conditions: Precipitation  Remains of wildlife collected?  \
# 0                      None                           False
# 1                      None                           False
#
#    Remains of wildlife sent to Smithsonian  \
# 0                                    False
# 1                                    False
#
#                                              Remarks Wildlife: Size  \
# 0  FLT 753. PILOT REPTD A HUNDRED BIRDS ON UNKN T...         Medium
# 1  102 CARCASSES FOUND. 1 LDG LIGHT ON NOSE GEAR ...          Small
#
#   Conditions: Sky      Wildlife: Species Pilot warned of birds or wildlife?  \
# 0        No Cloud  Unknown bird - medium                                  N
# 1      Some Cloud            Rock pigeon                                  Y
#
#    Cost: Total $  Feet above ground  Number of people injured  \
# 0          30736             1500.0                         0
# 1              0                0.0                         0
#
#   Is Aircraft Large?  Year
# 0                Yes  2000
# 1                 No  2001

# %%
plt.figure(figsize=(9,5))

Data.groupby('Effect: Impact to flight')['Effect: Indicated Damage'].sum().sort_values(ascending= False).plot.bar()
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(9,5))

Data.groupby('When: Phase of flight')['Effect: Indicated Damage'].sum().sort_values(ascending= False).plot.bar()
plt.xticks(rotation=0)
plt.show()

# %%
Data.head(2)
# Out:
#   Aircraft: Type                Airport: Name Altitude bin  \
# 0       Airplane                 LAGUARDIA NY    > 1000 ft
# 1       Airplane  DALLAS/FORT WORTH INTL ARPT    < 1000 ft
#
#   Aircraft: Make/Model Wildlife: Number struck  \
# 0            B-737-400                Over 100
# 1                MD-80                Over 100
#
#    Wildlife: Number Struck Actual Effect: Impact to flight FlightDate  \
# 0                             859         Engine Shut Down 2000-11-23
# 1                             424                     None 2001-07-25
#
#    Effect: Indicated Damage  Aircraft: Number of engines?  \
# 0                         1                             2
# 1                         1                             2
#
#   Aircraft: Airline/Operator Origin State When: Phase of flight  \
# 0                US AIRWAYS*     New York                 Climb
# 1          AMERICAN AIRLINES        Texas          Landing Roll
#
#   Conditions: Precipitation  Remains of wildlife collected?  \
# 0                      None                           False
# 1                      None                           False
#
#    Remains of wildlife sent to Smithsonian  \
# 0                                    False
# 1                                    False
#
#                                              Remarks Wildlife: Size  \
# 0  FLT 753. PILOT REPTD A HUNDRED BIRDS ON UNKN T...         Medium
# 1  102 CARCASSES FOUND. 1 LDG LIGHT ON NOSE GEAR ...          Small
#
#   Conditions: Sky      Wildlife: Species Pilot warned of birds or wildlife?  \
# 0        No Cloud  Unknown bird - medium                                  N
# 1      Some Cloud            Rock pigeon                                  Y
#
#    Cost: Total $  Feet above ground  Number of people injured  \
# 0          30736             1500.0                         0
# 1              0                0.0                         0
#
#   Is Aircraft Large?  Year
# 0                Yes  2000
# 1                 No  2001

# %%
Data.groupby('Is Aircraft Large?')['Effect: Indicated Damage'].sum().sort_values(ascending= False).plot.bar()
plt.xticks(rotation=0)
plt.show()

# %%
Data[(Data['Altitude bin'] == '< 1000 ft') & (Data['Number of people injured'] > 0)]
# Out:
#       Aircraft: Type                   Airport: Name Altitude bin  \
# 233         Airplane             TROY MUNICIPAL ARPT    < 1000 ft
# 781         Airplane               ROGUE VALLEY INTL    < 1000 ft
# 2781        Airplane  FORT LAUDERDALE/HOLLYWOOD INTL    < 1000 ft
# 4426        Airplane               ST LOUIS DOWNTOWN    < 1000 ft
# 5829        Airplane                SAN ANTONIO INTL    < 1000 ft
# 7196        Airplane    ORLANDO SANFORD INTL AIRPORT    < 1000 ft
# 24995       Airplane                QUINN FIELD ARPT    < 1000 ft
#
#       Aircraft: Make/Model Wildlife: Number struck  \
# 233             LEARJET-60                 2 to 10
# 781            DHC8 DASH 8                 2 to 10
# 2781                 C-402                 2 to 10
# 4426            LEARJET-24               11 to 100
# 5829                 BE-95                       1
# 7196                 C-172                       1
# 24995            MAULE M-7                       1
#
#        Wildlife: Number Struck Actual Effect: Impact to flight FlightDate  \
# 233                                 3                    Other 2001-01-14
# 781                                 4    Precautionary Landing 2003-01-08
# 2781                                7    Precautionary Landing 2009-02-16
# 4426                               33         Engine Shut Down 2003-11-12
# 5829                                1                     None 2001-02-25
# 7196                                1    Precautionary Landing 2002-06-06
# 24995                               1    Precautionary Landing 2011-10-01
#
#        Effect: Indicated Damage  Aircraft: Number of engines?  \
# 233                           1                             2
# 781                           1                             2
# 2781                          1                             2
# 4426                          1                             2
# 5829                          1                             2
# 7196                          1                             1
# 24995                         1                             1
#
#       Aircraft: Airline/Operator Origin State When: Phase of flight  \
# 233                     BUSINESS      Alabama          Landing Roll
# 781                  HORIZON AIR       Oregon              Approach
# 2781                    BUSINESS      Florida                 Climb
# 4426                    BUSINESS     Illinois                 Climb
# 5829             PRIVATELY OWNED        Texas              Approach
# 7196                    BUSINESS      Florida               Descent
# 24995                   BUSINESS     Nebraska                 Climb
#
#       Conditions: Precipitation  Remains of wildlife collected?  \
# 233                        None                           False
# 781                        None                            True
# 2781                       None                            True
# 4426                       None                           False
# 5829                       None                           False
# 7196                       None                           False
# 24995                      None                            True
#
#        Remains of wildlife sent to Smithsonian  \
# 233                                      False
# 781                                       True
# 2781                                     False
# 4426                                     False
# 5829                                     False
# 7196                                     False
# 24995                                    False
#
#                                                  Remarks Wildlife: Size  \
# 233    HIT 2 DEER AND RAN OFF RWY. THRUST REVERSERS W...          Large
# 781    7-8 BIRDS SUDDENLY APPEARED I FRONT OF A/C. SE...         Medium
# 2781   PILOT REPTD AT 600 FT BEING STRUCK BY A FLOCK ...          Large
# 4426   A/C INGESTED LITTLE BLACK BIRDS IN BOTH ENGS C...          Small
# 5829   AFTER BEING CLEARED TO LAND, PILOT SAW A BIRD ...          Large
# 7196   BIRD CAME THRU WINDSHLD AND INJURED STUDENT PI...          Large
# 24995  2 MEN INJURED WITH CUTS IN FACE. EMERGENCY LAN...         Medium
#
#       Conditions: Sky     Wildlife: Species  \
# 233          No Cloud     White-tailed deer
# 781          No Cloud          Lesser scaup
# 2781       Some Cloud         Black vulture
# 4426         No Cloud  Unknown bird - small
# 5829         No Cloud         Black vulture
# 7196       Some Cloud        Turkey vulture
# 24995        No Cloud                 Ducks
#
#       Pilot warned of birds or wildlife?  Cost: Total $  Feet above ground  \
# 233                                    N       12397751                0.0
# 781                                    N         123476             1000.0
# 2781                                   Y              0              600.0
# 4426                                   N         926070              500.0
# 5829                                   N          26553              150.0
# 7196                                   N           1382             1000.0
# 24995                                  N          14000              300.0
#
#        Number of people injured Is Aircraft Large?  Year
# 233                           2                 No  2001
# 781                           1                 No  2003
# 2781                          1                 No  2009
# 4426                          6                 No  2003
# 5829                          1                 No  2001
# 7196                          2                 No  2002
# 24995                         2                 No  2011

# %%
Data[(Data['Altitude bin'] == '> 1000 ft') & (Data['Number of people injured'] > 0)]['Number of people injured'].sum()
# Out:
# 6
