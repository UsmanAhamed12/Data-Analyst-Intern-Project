# %% [markdown]
# # Amazon Sales Data Cleaning

# %%
## import libraries

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
### import Dataset

Data = pd.read_csv('/Users/inazawaelectronics/Desktop/Data-Analyst-Intern-Project/AMAZON SALES PROJECT/Data/Amazon Sales data.csv')
Data.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H  5/28/2010  669165933  6/27/2010        9925
# 1        Online              C  8/22/2012  963881480  9/15/2012        2804
# 2       Offline              L   5/2/2014  341417157   5/8/2014        1779
# 3        Online              C  6/20/2014  514321792   7/5/2014        8102
# 4       Offline              L   2/1/2013  115456712   2/6/2013        5062
#
# ...

# %%
## See shape of the dataset
Data.shape
# Out:
# (100, 14)

# %%
## indentify the duplicate rows in dataset
Data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### No duplicated values in this dataset

# %%
### find NAN Values
Data.isnull().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %% [markdown]
# ### No NAN values in this dataset

# %%
Data.describe().T
# Out:
#                count          mean           std           min           25%  \
# Order ID       100.0  5.550204e+08  2.606153e+08  1.146066e+08  3.389225e+08
# Units Sold     100.0  5.128710e+03  2.794485e+03  1.240000e+02  2.836250e+03
# Unit Price     100.0  2.767613e+02  2.355922e+02  9.330000e+00  8.173000e+01
# Unit Cost      100.0  1.910480e+02  1.882082e+02  6.920000e+00  3.584000e+01
# Total Revenue  100.0  1.373488e+06  1.460029e+06  4.870260e+03  2.687212e+05
# Total Cost     100.0  9.318057e+05  1.083938e+06  3.612240e+03  1.688680e+05
# Total Profit   100.0  4.416820e+05  4.385379e+05  1.258020e+03  1.214436e+05
#
#                         50%           75%           max
# Order ID       5.577086e+08  7.907551e+08  9.940222e+08
# Units Sold     5.382500e+03  7.369000e+03  9.925000e+03
# Unit Price     1.798800e+02  4.372000e+02  6.682700e+02
# Unit Cost      1.072750e+02  2.633300e+02  5.249600e+02
# Total Revenue  7.523144e+05  2.212045e+06  5.997055e+06
# ...

# %%
sns.distplot(Data['Total Profit'], bins= 50)
# Out:
# /var/folders/8h/34w8609j6936zp6y_871bvk00000gn/T/ipykernel_2172/941039246.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Data['Total Profit'], bins= 50)
# <Axes: xlabel='Total Profit', ylabel='Density'>

# %%
Data['Total Profit'].quantile((0.25,0.75,1))
# Out:
# 0.25     121443.585
# 0.75     635828.800
# 1.00    1719922.040
# Name: Total Profit, dtype: float64

# %%
Data['Total Profit'].max()
# Out:
# 1719922.04

# %%
sns.boxplot( Data)
# Out:
# <Axes: >

# %%
for feature in Data.select_dtypes('number'):
    sns.distplot(Data[feature], bins = 50)
    plt.show()
# Out:
# /var/folders/8h/34w8609j6936zp6y_871bvk00000gn/T/ipykernel_2172/2436591974.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Data[feature], bins = 50)
# /var/folders/8h/34w8609j6936zp6y_871bvk00000gn/T/ipykernel_2172/2436591974.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# ...

# %%
for feature in Data.columns:
    print(f'{feature} has {len(Data[feature].unique())} categories')
# Out:
# Region has 7 categories
# Country has 76 categories
# Item Type has 12 categories
# Sales Channel has 2 categories
# Order Priority has 4 categories
# Order Date has 100 categories
# Order ID has 100 categories
# Ship Date has 99 categories
# Units Sold has 99 categories
# Unit Price has 12 categories
# Unit Cost has 12 categories
# Total Revenue has 100 categories
# Total Cost has 100 categories
# Total Profit has 100 categories

# %%
## identify datatypes
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    object
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    object
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 11.1+ KB

# %%
### change Order Date, Ship Date fetures to datetime

Data['Order Date'] = pd.to_datetime(Data['Order Date'])
Data['Ship Date'] = pd.to_datetime(Data['Ship Date'])

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    datetime64[ns]
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    datetime64[ns]
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
# dtypes: datetime64[ns](2), float64(5), int64(2), object(5)
# memory usage: 11.1+ KB

# %%
## export cleeaned Data set

Data.to_csv('cleaned_amazon_sales.csv', index= False)
